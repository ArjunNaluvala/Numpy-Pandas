# %% [markdown]
# ##### import the Diamond dataset

# %%
import pandas as pd

# %%
diamonds_data = pd.read_csv('diamonds.csv')

diamonds_df = pd.DataFrame(diamonds_data)
diamonds_df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# 1      3.84  2.31
# 2      4.07  2.31
# 3      4.23  2.63
# 4      4.35  2.75
# ...     ...   ...
# 53935  5.76  3.50
# 53936  5.75  3.61
# 53937  5.68  3.56
# 53938  6.12  3.74
# 53939  5.87  3.64
#
# [53940 rows x 11 columns]

# %% [markdown]
# ###### 1. Write a Pandas program to find the number of rows and columns and data type of each column of diamonds Dataframe.

# %%
### code here

print('The Number of rows and columns are :',diamonds_df.shape)
print('\nData type of each column:')
diamonds_df.dtypes
# Out:
# The Number of rows and columns are : (53940, 11)
#
# Data type of each column:
# Unnamed: 0      int64
# carat         float64
# cut            object
# color          object
# clarity        object
# depth         float64
# table         float64
# price           int64
# x             float64
# y             float64
# z             float64
# dtype: object

# %% [markdown]
# ##### 2. Write a Pandas program to summarize only 'object' columns of the diamonds Dataframe.

# %%
### code here

diamonds_df.select_dtypes(include='object').describe()
# Out:
#           cut  color clarity
# count   53940  53940   53940
# unique      5      7       8
# top     Ideal      G     SI1
# freq    21551  11292   13065

# %% [markdown]
# ###### 3. Write a Pandas program to remove the second column of the diamonds Dataframe. (don't use original dataset)

# %%
### code here

diamonds_df.drop(diamonds_df.columns[1], axis=1)
# Out:
#        Unnamed: 0        cut color clarity  depth  table  price     x     y  \
# 0               1      Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1               2    Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2               3       Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3               4    Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4               5       Good     J     SI2   63.3   58.0    335  4.34  4.35
# ...           ...        ...   ...     ...    ...    ...    ...   ...   ...
# 53935       53936      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76
# 53936       53937       Good     D     SI1   63.1   55.0   2757  5.69  5.75
# 53937       53938  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68
# 53938       53939    Premium     H     SI2   61.0   58.0   2757  6.15  6.12
# 53939       53940      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87
#
#           z
# 0      2.43
# 1      2.31
# 2      2.31
# 3      2.63
# 4      2.75
# ...     ...
# 53935  3.50
# 53936  3.61
# 53937  3.56
# 53938  3.74
# 53939  3.64
#
# [53940 rows x 10 columns]

# %% [markdown]
# ###### 4. Write a Pandas program to remove multiple rows at once (axis=0 refers to rows) from diamonds dataframe. (dont use original dataset)

# %%
### code here

diamonds_df.drop([1,3,5],axis=0)
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 6               7   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95
# 7               8   0.26  Very Good     H     SI1   61.9   55.0    337  4.07
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# 2      4.07  2.31
# 4      4.35  2.75
# 6      3.98  2.47
# 7      4.11  2.53
# ...     ...   ...
# 53935  5.76  3.50
# 53936  5.75  3.61
# 53937  5.68  3.56
# 53938  6.12  3.74
# 53939  5.87  3.64
#
# [53937 rows x 11 columns]

# %% [markdown]
# ###### 5. Write a Pandas program to sort the 'cut' Series in ascending order (returns a Series) of diamonds Dataframe.

# %%
### code here

diamonds_df['cut'].sort_values()
# Out:
# 3850          Fair
# 51464         Fair
# 51466         Fair
# 10237         Fair
# 10760         Fair
#            ...
# 7402     Very Good
# 43101    Very Good
# 16893    Very Good
# 16898    Very Good
# 21164    Very Good
# Name: cut, Length: 53940, dtype: object

# %% [markdown]
# ###### 6. Write a Pandas program to sort the entire diamonds DataFrame by the 'carat' Series in ascending and descending order.

# %%
### code here

diamonds_df.sort_values(by=['carat','carat'],ascending=[True,False])
# Out:
#        Unnamed: 0  carat      cut color clarity  depth  table  price      x  \
# 14             15   0.20  Premium     E     SI2   60.2   62.0    345   3.79
# 31591       31592   0.20  Premium     E     VS2   59.8   62.0    367   3.79
# 31592       31593   0.20  Premium     E     VS2   59.0   60.0    367   3.81
# 31593       31594   0.20  Premium     E     VS2   61.1   59.0    367   3.81
# 31594       31595   0.20  Premium     E     VS2   59.7   62.0    367   3.84
# ...           ...    ...      ...   ...     ...    ...    ...    ...    ...
# 25998       25999   4.01  Premium     I      I1   61.0   61.0  15223  10.14
# 25999       26000   4.01  Premium     J      I1   62.5   62.0  15223  10.02
# 27130       27131   4.13     Fair     H      I1   64.8   61.0  17329  10.00
# 27630       27631   4.50     Fair     J      I1   65.8   58.0  18531  10.23
# 27415       27416   5.01     Fair     J      I1   65.5   59.0  18018  10.74
#
#            y     z
# 14      3.75  2.27
# 31591   3.77  2.26
# 31592   3.78  2.24
# 31593   3.78  2.32
# 31594   3.80  2.28
# ...      ...   ...
# 25998  10.10  6.17
# 25999   9.94  6.24
# 27130   9.85  6.43
# 27630  10.16  6.72
# 27415  10.54  6.98
#
# [53940 rows x 11 columns]

# %% [markdown]
# ###### 7. Write a Pandas program to filter the DataFrame rows to only show carat weight at least 0.3.

# %%
#### code here

diamonds_df[diamonds_df['carat']>=0.3]
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 10             11   0.30       Good     J     SI1   64.0   55.0    339  4.25
# 13             14   0.31      Ideal     J     SI2   62.2   54.0    344  4.35
# 15             16   0.32    Premium     E      I1   60.9   58.0    345  4.38
# 16             17   0.30      Ideal     I     SI2   62.0   54.0    348  4.31
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 4      4.35  2.75
# 10     4.28  2.73
# 13     4.37  2.71
# 15     4.42  2.68
# 16     4.34  2.68
# ...     ...   ...
# 53935  5.76  3.50
# 53936  5.75  3.61
# 53937  5.68  3.56
# 53938  6.12  3.74
# 53939  5.87  3.64
#
# [52341 rows x 11 columns]

# %% [markdown]
# ###### 8.  Write a Pandas program to find the details of the diamonds where length>5, width>5 and depth>5.

# %%
### code here 

diamonds_df[(diamonds_df['x']>5) & (diamonds_df['y']>5) & (diamonds_df['z']>5)]
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 11778       11779   1.83       Fair     J      I1   70.0   58.0   5083  7.34
# 13002       13003   2.14       Fair     J      I1   69.4   57.0   5405  7.74
# 13118       13119   2.15       Fair     J      I1   65.5   57.0   5430  8.01
# 13562       13563   1.96       Fair     F      I1   66.6   60.0   5554  7.59
# 13757       13758   2.22       Fair     J      I1   66.7   56.0   5607  8.04
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 27748       27749   2.00  Very Good     G     SI1   63.5   56.0  18818  7.90
# 27749       27750   2.29    Premium     I     VS2   60.8   60.0  18823  8.50
# 48410       48411   0.51  Very Good     E     VS1   61.8   54.7   1970  5.12
# 49189       49190   0.51      Ideal     E     VS1   61.8   55.0   2075  5.15
# 49905       49906   0.50  Very Good     G    VVS1   63.7   58.0   2180  5.01
#
#            y      z
# 11778   7.28   5.12
# 13002   7.70   5.36
# 13118   7.95   5.23
# 13562   7.56   5.04
# 13757   8.02   5.36
# ...      ...    ...
# 27748   7.97   5.04
# 27749   8.47   5.16
# 48410   5.15  31.80
# 49189  31.80   5.12
# 49905   5.04   5.06
#
# [1457 rows x 11 columns]

# %% [markdown]
# ###### 9. Write a Pandas program to calculate the mean of each row of diamonds DataFrame.

# %%
### code here

diamonds_df.mean(axis=1, numeric_only=True)
# Out:
# 0          56.76125
# 1          57.38125
# 2          57.82000
# 3          58.71875
# 4          59.13125
#             ...
# 53935    7103.31625
# 53936    7103.48375
# 53937    7104.17500
# 53938    7103.98375
# 53939    7103.78625
# Length: 53940, dtype: float64

# %% [markdown]
# ###### 10. Write a Pandas program to calculate the mean of price for each cut  and find maximum top 3 of diamonds DataFrame.

# %%
#### code here

diamonds_df.groupby('cut')['price'].mean().sort_values(ascending=False).head(3)
# Out:
# cut
# Premium      4584.257704
# Fair         4358.757764
# Very Good    3981.759891
# Name: price, dtype: float64

# %% [markdown]
# ##### 11. Write a Pandas program to calculate count, minimum, maximum price for each cut of diamonds DataFrame.

# %%
### code here

diamonds_df.groupby('cut')['price'].agg(['count','min','max'])
# Out:
#            count  min    max
# cut
# Fair        1610  337  18574
# Good        4906  327  18788
# Ideal      21551  326  18806
# Premium    13791  326  18823
# Very Good  12082  336  18818

# %% [markdown]
# ###### 12. Write a Pandas program to display and count the unique values in cut series of diamonds DataFrame.

# %%
### code here

print(diamonds_df['cut'].unique())

print(diamonds_df['cut'].nunique())
# Out:
# ['Ideal' 'Premium' 'Good' 'Very Good' 'Fair']
# 5

# %% [markdown]
# ###### 13.  Write a Pandas program to count the number of missing values in each Series of diamonds DataFrame.

# %%
### code here

diamonds_df.isnull().sum()
# Out:
# Unnamed: 0    0
# carat         0
# cut           0
# color         0
# clarity       0
# depth         0
# table         0
# price         0
# x             0
# y             0
# z             0
# dtype: int64

# %% [markdown]
# ###### 14. Write a Pandas program to calculate the multiply of x, y and z for each cut of diamonds DataFrame.

# %%
### code here

diamonds_df.groupby('cut').apply(lambda x: (x['x'] * x['y'] * x['z']).mean())
# Out:
# cut
# Fair         164.950549
# Good         136.257267
# Ideal        115.394912
# Premium      145.052128
# Very Good    130.999722
# dtype: float64

# %% [markdown]
# ##### 15. Write a Pandas program to read rows 0 through 2 (inclusive), columns ‘color’ and ‘price’ of diamonds DataFrame.

# %%
## code here

diamonds_df.loc[0:2,['color','price']]
# Out:
#   color  price
# 0     E    326
# 1     E    326
# 2     E    327

# %% [markdown]
# ###### 16. Write a Pandas program to read rows in positions 0 and 1, columns in positions 0 and 3 of diamonds DataFrame.

# %%
### code here

diamonds_df.iloc[[0,1],[0,3]]
# Out:
#    Unnamed: 0 color
# 0           1     E
# 1           2     E

# %% [markdown]
# ##### 17. Write a Pandas program to get randomly sample rows from diamonds DataFrame.

# %%
### code here

diamonds_df.sample(frac=1,random_state=42).reset_index(drop=True)
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0            1389   0.24      Ideal     G    VVS1   62.1   56.0    559  3.97
# 1           50053   0.58  Very Good     F    VVS2   60.0   57.0   2201  5.44
# 2           41646   0.40      Ideal     E    VVS2   62.1   55.0   1238  4.76
# 3           42378   0.43    Premium     E    VVS2   60.8   57.0   1304  4.92
# 4           17245   1.55      Ideal     E     SI2   62.3   55.0   6901  7.44
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       11285   1.05  Very Good     I     VS2   62.4   59.0   4975  6.48
# 53936       44733   0.47      Ideal     D     VS1   61.0   55.0   1617  5.03
# 53937       38159   0.33  Very Good     F      IF   60.3   58.0   1014  4.49
# 53938         861   0.90    Premium     J     SI1   62.8   59.0   2871  6.13
# 53939       15796   1.14    Premium     F     SI1   60.4   58.0   6320  6.82
#
#           y     z
# 0      4.00  2.47
# 1      5.42  3.26
# 2      4.74  2.95
# 3      4.89  2.98
# 4      7.37  4.61
# ...     ...   ...
# 53935  6.51  4.05
# 53936  5.01  3.06
# 53937  4.46  2.70
# 53938  6.03  3.82
# 53939  6.79  4.11
#
# [53940 rows x 11 columns]

# %% [markdown]
# ###### 18. Write a Pandas program to get sample 75% of the diamonds DataFrame's rows without replacement and store the remaining 25% of the rows in another DataFrame.

# %%
### code here

diamonds_75 = diamonds_df.sample(frac=0.75,random_state=42).reset_index(drop=True)

print("75% Sample:")
diamonds_75.head()
# Out:
# 75% Sample:
#    Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0        1389   0.24      Ideal     G    VVS1   62.1   56.0    559  3.97
# 1       50053   0.58  Very Good     F    VVS2   60.0   57.0   2201  5.44
# 2       41646   0.40      Ideal     E    VVS2   62.1   55.0   1238  4.76
# 3       42378   0.43    Premium     E    VVS2   60.8   57.0   1304  4.92
# 4       17245   1.55      Ideal     E     SI2   62.3   55.0   6901  7.44
#
#       y     z
# 0  4.00  2.47
# 1  5.42  3.26
# 2  4.74  2.95
# 3  4.89  2.98
# 4  7.37  4.61

# %%
diamonds_25 = diamonds_df.drop(diamonds_75.index).reset_index(drop=True)

print("Remaining 25%:")
diamonds_25.head()
# Out:
# Remaining 25%:
#    Unnamed: 0  carat    cut color clarity  depth  table  price     x     y  \
# 0       40456    0.5  Ideal     H     SI1   62.2   57.0   1140  5.07  5.09
# 1       40457    0.5  Ideal     H     SI1   62.4   56.0   1140  5.07  5.09
# 2       40458    0.5  Ideal     H     SI1   62.1   58.0   1140  5.04  5.07
# 3       40459    0.5  Ideal     H     SI1   62.5   57.0   1140  5.06  5.08
# 4       40460    0.5  Ideal     H     SI1   62.0   56.0   1140  5.08  5.11
#
#       z
# 0  3.16
# 1  3.17
# 2  3.14
# 3  3.17
# 4  3.16

# %% [markdown]
# ###### 19. Write a Pandas program to read the diamonds DataFrame and detect duplicate color.

# %%
#### code here

diamonds_df['color'].duplicated()
# Out:
# 0        False
# 1         True
# 2         True
# 3        False
# 4        False
#          ...
# 53935     True
# 53936     True
# 53937     True
# 53938     True
# 53939     True
# Name: color, Length: 53940, dtype: bool

# %% [markdown]
# ###### 20. Write a Pandas program to count the duplicate rows of diamonds DataFrame.

# %%
#### code here

diamonds_df.duplicated().sum()
# Out:
# 0
